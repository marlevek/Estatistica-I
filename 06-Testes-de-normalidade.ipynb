# %%
from scipy import stats
from scipy.stats import norm, skewnorm
import matplotlib.pyplot as plt

# %%
# Criando uma variável com dados em uma distribuição normal com a função rvs (100 elementos)
dados = norm.rvs(size=100)
dados
# Out:
# array([ 0.2657103 , -0.79611287,  0.52848853,  0.53613492,  0.44617891,
#         1.36551389,  0.90159545,  0.82011598,  2.03727477,  0.23677952,
#        -0.23583049,  0.35130141, -0.10504734, -1.0406429 ,  0.51600378,
#         1.05932127, -1.686254  ,  1.72498248,  0.53940961, -2.41301615,
#         0.24252734, -1.60867858, -1.01765846, -0.3389709 , -1.88103493,
#        -0.37736832, -0.01575248, -0.75585559, -1.28780728, -0.0743007 ,
#        -0.26973749, -0.46931457, -1.10454575, -0.4924004 ,  1.01737219,
#        -0.73616648, -0.05100254, -1.60697257, -0.26591238, -0.59815384,
#         0.90493302, -0.17191546,  2.05253286, -0.45040008, -0.08490852,
#         0.04203472,  0.5964409 , -1.00928789,  0.88886062, -0.90448223,
#         1.33577311, -1.5073055 ,  1.74140052, -0.43873972,  1.98923105,
#        -0.12765165, -0.67306725, -1.53985609, -0.38693081, -0.66610333,
#         0.35997486,  1.47359298,  1.67938102,  0.91482691, -0.5857875 ,
#         0.07891531, -0.63753413, -0.59934673, -0.23351123, -0.48304898,
#         0.37746778, -0.84674909,  0.93104024,  0.3614046 ,  0.94350291,
#        -0.94815919,  0.77120159,  1.70490116, -0.80755439,  1.6082553 ,
#         2.2538279 ,  0.41048777, -0.22455883, -0.1452774 ,  1.84565253,
#         0.52760528,  1.06382069,  0.46109668, -0.08281158,  2.0219226 ,
#        -0.48330345,  2.15163184, -1.41565035, -0.14362193, -1.38933072,
#        -1.51868868,  0.23434753, -1.25768658, -0.14838262,  0.12538596])

# %%
# Histrograma
plt.hist(dados, bins=20)
plt.title('Dados')
# Out:
# Text(0.5, 1.0, 'Dados')

# %%
# Geração de gráfico para verificar se a distribuição é normal
fig, ax = plt.subplots()
stats.probplot(dados, fit=True, plot=ax)
plt.show()

# %%
# Execução do teste de Shapiro
stats.shapiro(dados)
# Out:
# ShapiroResult(statistic=0.9826393127441406, pvalue=0.21223923563957214)

# %% [markdown]
# Observar que o pvalue > 0.05, logo não podemos rejeitar a hipótese nula, de que a distribuição é normal.

# %% [markdown]
# ### Dados não normais

# %%
dados2 = skewnorm.rvs(4, size = 1000)

# %%
# histograma
plt.hist(dados2, bins=20)
plt.title('Dados')
# Out:
# Text(0.5, 1.0, 'Dados')

# %%
# Geração do gráfico para verificar se a distribuição é normal
fit, ax = plt.subplots()
stats.probplot(dados2, fit=True, plot=ax)
plt.show()

# %%
stats.shapiro(dados2)
# Out:
# ShapiroResult(statistic=0.9658969044685364, pvalue=1.4949343778397454e-14)
